# %% [markdown]
# # 0. Librerias

# %%
# Genérica
# -----------------------------------------------------------------------------
from time import time
import session_info


# Tratamientos datos
# -----------------------------------------------------------------------------
import pandas as pd
import numpy as np


# scikit-learn
# -----------------------------------------------------------------------------
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import FunctionTransformer


# LightGBM
# -----------------------------------------------------------------------------
import lightgbm as lgb


# Gráficos
# -----------------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt


session_info.show(html=False)
# Out:
# -----
# lightgbm            3.3.5
# matplotlib          3.7.2
# numpy               1.23.5
# pandas              1.5.3
# seaborn             0.12.2
# session_info        1.0.0
# sklearn             1.3.0
# -----
# IPython             8.14.0
# jupyter_client      8.3.0
# jupyter_core        5.3.1
# notebook            6.5.4
# -----
# Python 3.10.11 (main, May 16 2023, 00:28:57) [GCC 11.2.0]
# Linux-5.15.0-86-generic-x86_64-with-glibc2.31
# -----
# Session information updated at 2023-10-11 19:19

# %%
# Funciones
# -----------------------------------------------------------------------------
def your_function(xxx):
    pass

# %% [markdown]
# # 1. Cargar datos

# %%
# Ruta
path = './data/tablon-sell-in-3.csv'


# Cargar datos
df = pd.read_csv(
    path,
    sep=';',
    dtype={
        'Epoca_Covid': 'category',
        'Anio': 'category',
        'Trimestre': 'category',
        'Mes': 'category',
        'Cliente': 'category',
        'Tipo_Cliente': 'category',
        'Distribuidor_MSM': 'category',
        'Codigo_Postal': 'category',
        'Area_Dist': 'category',
        'Zona': 'category',
        'ID_CCAA': 'category',
        'ID_Provincia': 'category',
        'Gama': 'category',
        'Formato': 'category'
    })


# Castear tipo de dato
fcols = df.select_dtypes('float').columns
icols = df.select_dtypes('integer').columns

df[fcols] = df[fcols].apply(pd.to_numeric, downcast='float')
df[icols] = df[icols].apply(pd.to_numeric, downcast='integer')


# Eliminar año 2020
filtro = (df.Anio != '2020')
# filtro = (df.Anio == '2022') & (df.Tipo_Cliente == 'CON')
# filtro = (df.Cliente == '542516')
df = df[filtro]


df.head()
# Out:
#     Fecha Epoca_Covid  Anio Trimestre Mes  Cliente Tipo_Cliente  \
# 0  201809   pre-covid  2018        T3  09  1822277          DHC
# 1  201809   pre-covid  2018        T3  09  1822277          DHC
# 2  201809   pre-covid  2018        T3  09  1822277          DHC
# 3  201809   pre-covid  2018        T3  09  1822423          DHC
# 4  201809   pre-covid  2018        T3  09  1822423          DHC
#
#   Distribuidor_MSM Codigo_Postal Area_Dist  ...        IPRI  \
# 0                0         08241        ZZ  ...  102.370003
# 1                0         08241        ZZ  ...  102.370003
# 2                0         08241        ZZ  ...  102.370003
# 3                0         07610        ZZ  ...  103.709999
# 4                0         07610        ZZ  ...  103.709999
#
#   Temperatura_Minima Temperatura_Media Temperatura_Maxima Precipitacion  \
# 0          19.420000         23.410000          27.410000     32.580002
# 1          19.420000         23.410000          27.410000     32.580002
# 2          19.420000         23.410000          27.410000     32.580002
# 3          20.459999         24.459999          28.450001     47.189999
# 4          20.459999         24.459999          28.450001     47.189999
#
#    Sell_In_3  Sell_In_2  Sell_In_1  Sell_In      STRATIO_CREATED_DATE
# 0       0.55       0.79       0.63     0.48  2023-09-06T22:37:10.734Z
# 1       2.40       3.00       3.30     2.70  2023-09-06T22:37:10.734Z
# 2       1.27       0.95       1.11     0.95  2023-09-06T22:37:10.734Z
# 3       0.20       0.00       0.20     0.10  2023-09-06T22:37:10.734Z
# 4       8.50       7.00       6.50     7.50  2023-09-06T22:37:10.734Z
#
# [5 rows x 54 columns]

# %%
# Columnas del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1897461 entries, 0 to 2232236
# Data columns (total 54 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Fecha                       int32
#  1   Epoca_Covid                 category
#  2   Anio                        category
#  3   Trimestre                   category
#  4   Mes                         category
#  5   Cliente                     category
#  6   Tipo_Cliente                category
#  7   Distribuidor_MSM            category
#  8   Codigo_Postal               category
#  9   Area_Dist                   category
#  10  Zona                        category
#  11  ID_CCAA                     category
#  12  ID_Provincia                category
#  13  Gama                        category
#  14  Formato                     category
#  15  Num_PdV_CI                  float32
#  16  Num_PdV_RU                  float32
#  17  Num_PdV_TU                  float32
#  18  Impactos_TV                 float64
#  19  Impactos_OOH                float64
#  20  Impresiones_Meta            float32
#  21  Impresiones_Pint            float32
#  22  Impresiones_Digi            float32
#  23  Sell_In_PP                  float64
#  24  Marketing_Nacional          float64
#  25  Trade_Marketing             float64
#  26  Marketing_PLV               float64
#  27  Distancia_CdP               float32
#  28  Dispersion_PdV              float32
#  29  Volumen_Solicitado          float32
#  30  Volumen_Entregado_Perfecto  float32
#  31  Nivel_Servicio              float32
#  32  Tarifa_Eur_Hl               float64
#  33  Margen_Distribuidor         float32
#  34  Num_Festivos                float32
#  35  Num_Festivos_AI             int8
#  36  Egatur                      float32
#  37  Frontur                     float64
#  38  Familitur                   float32
#  39  Movimientos_Entrada         float64
#  40  Movimientos_Salida          float64
#  41  Movimientos_Neto            float64
#  42  IPC                         float32
#  43  IPI                         float32
#  44  IPRI                        float32
#  45  Temperatura_Minima          float32
#  46  Temperatura_Media           float32
#  47  Temperatura_Maxima          float32
#  48  Precipitacion               float32
#  49  Sell_In_3                   float32
#  50  Sell_In_2                   float32
#  51  Sell_In_1                   float32
#  52  Sell_In                     float32
#  53  STRATIO_CREATED_DATE        object
# dtypes: category(14), float32(26), float64(11), int32(1), int8(1), object(1)
# memory usage: 415.1+ MB

# %%
# Eliminar columnas
df = df.drop(columns=[
    'Fecha',
    'Anio',
    'Cliente',
    'Frontur',
    'Temperatura_Minima',
    'Temperatura_Maxima',
    'Movimientos_Entrada',
    'Movimientos_Salida',
    'Volumen_Solicitado',
    'STRATIO_CREATED_DATE'
])

# Eliminar registros con NaN
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1897461 entries, 0 to 2232236
# Data columns (total 44 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Epoca_Covid                 category
#  1   Trimestre                   category
#  2   Mes                         category
#  3   Tipo_Cliente                category
#  4   Distribuidor_MSM            category
#  5   Codigo_Postal               category
#  6   Area_Dist                   category
#  7   Zona                        category
#  8   ID_CCAA                     category
#  9   ID_Provincia                category
#  10  Gama                        category
#  11  Formato                     category
#  12  Num_PdV_CI                  float32
#  13  Num_PdV_RU                  float32
#  14  Num_PdV_TU                  float32
#  15  Impactos_TV                 float64
#  16  Impactos_OOH                float64
#  17  Impresiones_Meta            float32
#  18  Impresiones_Pint            float32
#  19  Impresiones_Digi            float32
#  20  Sell_In_PP                  float64
#  21  Marketing_Nacional          float64
#  22  Trade_Marketing             float64
#  23  Marketing_PLV               float64
#  24  Distancia_CdP               float32
#  25  Dispersion_PdV              float32
#  26  Volumen_Entregado_Perfecto  float32
#  27  Nivel_Servicio              float32
#  28  Tarifa_Eur_Hl               float64
#  29  Margen_Distribuidor         float32
#  30  Num_Festivos                float32
#  31  Num_Festivos_AI             int8
#  32  Egatur                      float32
#  33  Familitur                   float32
#  34  Movimientos_Neto            float64
#  35  IPC                         float32
#  36  IPI                         float32
#  37  IPRI                        float32
#  38  Temperatura_Media           float32
#  39  Precipitacion               float32
#  40  Sell_In_3                   float32
#  41  Sell_In_2                   float32
#  42  Sell_In_1                   float32
#  43  Sell_In                     float32
# dtypes: category(12), float32(23), float64(8), int8(1)
# memory usage: 322.2 MB

# %% [markdown]
# # 2. Modelos

# %% [markdown]
# ## 2.1. Sin feature engineering

# %% [markdown]
# ### 2.1.1. Modelo base

# %%
# Variable dependiente
target = 'Sell_In'

# Variables independientes
features = list(df.columns)
features.remove(target)

# Mostrar
print(f'Variable dependiente: {target}')
print(30*'-')
print(f'Variable independiente: {features}')
# Out:
# Variable dependiente: Sell_In
# ------------------------------
# Variable independiente: ['Epoca_Covid', 'Trimestre', 'Mes', 'Tipo_Cliente', 'Distribuidor_MSM', 'Codigo_Postal', 'Area_Dist', 'Zona', 'ID_CCAA', 'ID_Provincia', 'Gama', 'Formato', 'Num_PdV_CI', 'Num_PdV_RU', 'Num_PdV_TU', 'Impactos_TV', 'Impactos_OOH', 'Impresiones_Meta', 'Impresiones_Pint', 'Impresiones_Digi', 'Sell_In_PP', 'Marketing_Nacional', 'Trade_Marketing', 'Marketing_PLV', 'Distancia_CdP', 'Dispersion_PdV', 'Volumen_Entregado_Perfecto', 'Nivel_Servicio', 'Tarifa_Eur_Hl', 'Margen_Distribuidor', 'Num_Festivos', 'Num_Festivos_AI', 'Egatur', 'Familitur', 'Movimientos_Neto', 'IPC', 'IPI', 'IPRI', 'Temperatura_Media', 'Precipitacion', 'Sell_In_3', 'Sell_In_2', 'Sell_In_1']

# %%
# Seed
seed = 123

# Separar conjunto de test y entrenamiento
train, test = train_test_split(df, train_size=0.95, test_size=0.05, random_state=seed)

# %%
# Instanciar modelo
max_depth = 8

mlgb = lgb.LGBMRegressor(
    boosting_type = 'gbdt', # Gradient Boosting Decision Tree
    learning_rate = 0.1, # Boosting learning rate (default value)
    n_estimators = 1000, # Número de árboles (originalmente 1000)
    max_depth = max_depth, # Profundidad máxima del árbol [3, 12]
    num_leaves = 80, # Número de hojas máximo del árbol, <2^max_depth
    min_child_samples = 10, # Número mínimo de registros en una hoja
    bagging_fraction = 1.0, # Porcentaje de datos cogidos en cada re-sampling del Bagging
    bagging_freq = 0, # Frecuencia del Bagging
    feature_fraction = 0.9, # Feature sub-sampling
    reg_sqrt = True, # Raíz cuadrada del target, para variables a predecir con mucha variabilidad
    extra_trees = True, # Incremente velocidad, disminuye overfitting
    feature_pre_filter = False,
    random_state = seed,
    n_jobs = -1
)

# %%
# Pipeline
model_pipeline = Pipeline(steps=[("mlgb", mlgb)])

# %%
# Medir tiempo
tiempo_inicial = time()

# Entrenar modelo
model = model_pipeline.fit(train[features], train[target])

# Medir tiempo
tiempo_final = time()
tiempo_ejecucion = tiempo_final - tiempo_inicial

print('')
print(f'El tiempo de ejecución es de {tiempo_ejecucion/60} minutos')
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#
# El tiempo de ejecución es de 1.0372758070627848 minutos

# %%
# Cálculo de métricas
train_y_real = train[target]
train_y_pred = model.predict(train[features])

test_y_real = test[target]
test_y_pred = model.predict(test[features])

metric_test_r2 = round(r2_score(test_y_real, test_y_pred), 3)
metric_adj_test_r2 = round(1-(1-metric_test_r2)*(len(test)-1)/(len(test)-len(features)-1), 3)

metric_train_mae = round(mean_absolute_error(train_y_real, train_y_pred), 3)
metric_test_mae = round(mean_absolute_error(test_y_real, test_y_pred), 3)

metric_train_rmse = round(mean_squared_error(train_y_real, train_y_pred, squared=False), 3)
metric_test_rmse = round(mean_squared_error(test_y_real, test_y_pred, squared=False), 3)

metric_train_score = round(1.00 - (metric_train_mae / train_y_real.mean()), 3)
metric_test_score = round(1.00 - (metric_test_mae / test_y_real.mean()), 3)


# Mostrar
print('R2 Score')
print(50*'-')
print(f'Test R2: {metric_test_r2}')
print(f'Test R2 Adj: {metric_adj_test_r2}')
print('')

print('Score')
print(50*'-')
print(f'Train: {metric_train_score}')
print(f'Test: {metric_test_score}')
print('')

print('MAE')
print(50*'-')
print(f'Train: {metric_train_mae}')
print(f'Test: {metric_test_mae}')
print('')

print('RMSE')
print(50*'-')
print(f'Train: {metric_train_rmse}')
print(f'Test: {metric_test_rmse}')
print('')
# Out:
# R2 Score
# --------------------------------------------------
# Test R2: 0.963
# Test R2 Adj: 0.963
#
# Score
# --------------------------------------------------
# Train: 0.848
# Test: 0.806
#
# MAE
# --------------------------------------------------
# Train: 2.817
# Test: 3.707
#
# RMSE
# --------------------------------------------------
# Train: 19.308
# Test: 29.837

# %%
feature_imp = pd.DataFrame(sorted(zip(features, model[0].feature_importances_)), columns=['Feature', 'Value'])
feature_imp = feature_imp.sort_values(by=['Value'], ascending=False).reset_index(drop=True)
feature_imp
# Out:
#                        Feature  Value
# 0                          Mes   6714
# 1                 ID_Provincia   5970
# 2                Codigo_Postal   4356
# 3                Marketing_PLV   3493
# 4                    Sell_In_1   3442
# 5                      Formato   3200
# 6              Trade_Marketing   3123
# 7                   Sell_In_PP   3028
# 8                    Sell_In_3   2960
# 9                    Sell_In_2   2922
# 10          Marketing_Nacional   2841
# 11  Volumen_Entregado_Perfecto   2534
# 12                        Gama   2353
# 13                   Familitur   2219
# 14                 Epoca_Covid   2191
# 15                  Num_PdV_CI   1941
# 16                        Zona   1642
# 17               Precipitacion   1482
# 18                        IPRI   1385
# 19               Tarifa_Eur_Hl   1338
# 20              Dispersion_PdV   1306
# 21                Num_Festivos   1272
# 22            Impresiones_Meta   1215
# 23         Margen_Distribuidor   1199
# 24                 Impactos_TV   1189
# 25                   Area_Dist   1165
# 26                      Egatur   1107
# 27                         IPI   1104
# 28           Temperatura_Media   1083
# 29                  Num_PdV_TU   1082
# 30                   Trimestre   1005
# 31                     ID_CCAA    999
# 32            Movimientos_Neto    935
# 33                Tipo_Cliente    858
# 34            Distribuidor_MSM    798
# 35               Distancia_CdP    770
# 36                  Num_PdV_RU    757
# 37                         IPC    538
# 38             Num_Festivos_AI    443
# 39            Impresiones_Digi    364
# 40            Impresiones_Pint    277
# 41                Impactos_OOH    210
# 42              Nivel_Servicio    190

# %%
# Figure aesthetics
sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(8, 12))

# Barplot
sns.barplot(
    x='Value',
    y='Feature',
    data=feature_imp
)

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Features')

# Add values
ax.bar_label(ax.containers[0], label_type='edge', fmt='{:,.0f}', padding=5)

# Show the plot
sns.despine()

# %% [markdown]
# ### 2.1.1. Modelo optimizado

# %%
# scikit-learn
# -----------------------------------------------------------------------------
from sklearn.model_selection import train_test_split, KFold


# Optuna
# -----------------------------------------------------------------------------
import optuna
import optuna.integration.lightgbm as lgb
optuna.logging.set_verbosity(optuna.logging.FATAL)


# LightGBM
# -----------------------------------------------------------------------------
from lightgbm import early_stopping
from lightgbm import log_evaluation

# %%
# Instanciar optimizador
dtrain = lgb.Dataset(train[features], label=train[target])

# %%
# Parametros de optimización
params = {
    'objective': 'regression',
    'verbosity': -1,
    'metric': 'l1', # mean_absolute_error
    'boosting_type': 'gbdt',
    'max_depth': max_depth,
    'reg_sqrt': True,
    'seed': seed
    }

# %%
# Optimizador
tuner = lgb.LightGBMTunerCV(
    params,
    dtrain,
    folds=KFold(n_splits=3),
    #callbacks=[early_stopping(300), log_evaluation(100)]
    )

# %%
# Medir tiempo
tiempo_inicial = time()

# Ejecutar optmizador
tuner.run()

# Medir tiempo
tiempo_final = time()
tiempo_ejecucion = tiempo_final - tiempo_inicial

print('')
print(f'El tiempo de ejecución es de {tiempo_ejecucion/60} minutos')
# Out:
# feature_fraction, val_score: 8.367138: 100%|##############| 7/7 [02:09<00:00, 18.47s/it]
# num_leaves, val_score: 8.324440: 100%|##################| 20/20 [10:27<00:00, 31.36s/it]
# bagging, val_score: 8.324440: 100%|#####################| 10/10 [05:46<00:00, 34.65s/it]
# feature_fraction_stage2, val_score: 8.324440: 100%|#######| 6/6 [03:12<00:00, 32.15s/it]
# regularization_factors, val_score: 8.303001: 100%|######| 20/20 [07:29<00:00, 22.46s/it]
# min_data_in_leaf, val_score: 8.303001: 100%|##############| 5/5 [01:05<00:00, 13.00s/it]
# El tiempo de ejecución es de 30.17111965815226 minutos

# %%
# Mejores parámetros
best_params = tuner.best_params
best_params
# Out:
# {'objective': 'regression',
#  'verbosity': -1,
#  'metric': 'l1',
#  'boosting_type': 'gbdt',
#  'max_depth': 6,
#  'reg_sqrt': True,
#  'seed': 123,
#  'feature_pre_filter': False,
#  'lambda_l1': 7.3724649841075065,
#  'lambda_l2': 0.008512890141321892,
#  'num_leaves': 54,
#  'feature_fraction': 0.8,
#  'bagging_fraction': 1.0,
#  'bagging_freq': 0,
#  'min_child_samples': 20}

# %%
# LightGBM
# -----------------------------------------------------------------------------
import lightgbm as lgb

# %%
# Instanciar modelo
mlgb = lgb.LGBMRegressor(
    boosting_type = 'gbdt',
    learning_rate = 0.1,
    n_estimators = 1000,
    max_depth = max_depth,
    num_leaves = best_params['num_leaves'],
    min_child_samples = best_params['min_child_samples'],
    bagging_fraction = best_params['bagging_fraction'],
    bagging_freq = best_params['bagging_freq'],
    feature_fraction = best_params['feature_fraction'],
    reg_alpha = best_params['lambda_l1'],
    reg_lambda = best_params['lambda_l2'],
    extra_trees = True,
    reg_sqrt = True,
    feature_pre_filter = False,
    random_state = seed,
    n_jobs = -1
)


# Pipeline
model_pipeline = Pipeline(steps=[("mlgb", mlgb)])


# Entrenar modelo
model = model_pipeline.fit(train[features], train[target])


# Cálculo de métricas
metric_test_r2 = round(r2_score(test[target], model.predict(test[features])), 3)
metric_adj_test_r2 = round(1-(1-metric_test_r2)*(len(test)-1)/(len(test)-len(features)-1), 3)

metric_train_mae = round(mean_absolute_error(train[target], model.predict(train[features])), 3)
metric_test_mae = round(mean_absolute_error(test[target], model.predict(test[features])), 3)

metric_train_rmse = round(mean_squared_error(train[target], model.predict(train[features]), squared=False), 3)
metric_test_rmse = round(mean_squared_error(test[target], model.predict(test[features]), squared=False), 3)


# Mostrar
print('R2 Score')
print(50*'-')
print(f'Test R2: {metric_test_r2}')
print(f'Test R2 Adj: {metric_adj_test_r2}')
print('')

print('MAE')
print(50*'-')
print(f'Train: {metric_train_mae}')
print(f'Test: {metric_test_mae}')
print('')

print('RMSE')
print(50*'-')
print(f'Train: {metric_train_rmse}')
print(f'Test: {metric_test_rmse}')
print('')
# Out:
# R2 Score
# --------------------------------------------------
# Test R2: 0.965
# Test R2 Adj: 0.965
#
# MAE
# --------------------------------------------------
# Train: 3.379
# Test: 7.605
#
# RMSE
# --------------------------------------------------
# Train: 14.314
# Test: 39.911

# %%
model
# Out:
# Pipeline(steps=[('mlgb',
#                  LGBMRegressor(bagging_fraction=1.0, bagging_freq=0,
#                                feature_fraction=0.8, feature_pre_filter=False,
#                                max_depth=6, n_estimators=1000, num_leaves=54,
#                                random_state=123, reg_alpha=7.3724649841075065,
#                                reg_lambda=0.008512890141321892,
#                                reg_sqrt=True))])

# %%
feature_imp = pd.DataFrame(sorted(zip(features, model[0].feature_importances_)), columns=['Feature', 'Value'])
feature_imp.sort_values(by=['Value'], ascending=False)
# Out:
#                        Feature  Value
# 1                Codigo_Postal   6440
# 23                         Mes   3278
# 32                   Sell_In_1   3084
# 39             Trade_Marketing   2860
# 35                  Sell_In_PP   2690
# 22               Marketing_PLV   2553
# 41  Volumen_Entregado_Perfecto   2425
# 21          Marketing_Nacional   2234
# 33                   Sell_In_2   2215
# 34                   Sell_In_3   2154
# 11                ID_Provincia   1734
# 36               Tarifa_Eur_Hl   1624
# 20         Margen_Distribuidor   1505
# 18            Impresiones_Meta   1224
# 31               Precipitacion   1159
# 37           Temperatura_Media   1086
# 14                        IPRI    867
# 8                      Formato    823
# 13                         IPI    776
# 9                         Gama    769
# 28                  Num_PdV_CI    756
# 16                 Impactos_TV    734
# 2               Dispersion_PdV    727
# 24            Movimientos_Neto    692
# 12                         IPC    629
# 5                       Egatur    600
# 26                Num_Festivos    561
# 29                  Num_PdV_RU    541
# 25              Nivel_Servicio    516
# 7                    Familitur    380
# 30                  Num_PdV_TU    348
# 19            Impresiones_Pint    303
# 42                        Zona    292
# 3                Distancia_CdP    263
# 17            Impresiones_Digi    233
# 10                     ID_CCAA     76
# 40                   Trimestre     70
# 27             Num_Festivos_AI     63
# 4             Distribuidor_MSM     24
# 0                    Area_Dist     10
# 15                Impactos_OOH      5
# 6                  Epoca_Covid      0
# 38                Tipo_Cliente      0

# %%
test
# Out:
#         Epoca_Covid Trimestre Mes Tipo_Cliente Distribuidor_MSM Codigo_Postal  \
# 407595   post-covid        T1  02          CON                0         06225
# 419583   post-covid        T1  02          CON                0         41809
# 428870   post-covid        T1  03          CON                0         02630
# 1851591  post-covid        T3  08          CON                0         23700
# 402259   post-covid        T1  02          CON                0         49500
# ...             ...       ...  ..          ...              ...           ...
# 460015   post-covid        T2  04          CON                0         02007
# 1851047  post-covid        T3  08          CON                0         07800
# 1895545  post-covid        T3  09          CON                0         45300
# 1953511  post-covid        T4  11          CON                0         39792
# 1828973  post-covid        T3  07          CON                0         04740
#
#         Area_Dist  Zona ID_CCAA ID_Provincia  ... Movimientos_Neto  IPC  \
# 407595         Y4   Z13      11           06  ...           2862.0  0.8
# 419583         Y3  ZB13      01           41  ...        -130171.0  1.0
# 428870         Y2   ZB8      08           02  ...          -7375.0  3.7
# 1851591        Y3  ZC13      01           23  ...         -39137.0  0.4
# 402259         Y4   Z08      07           49  ...          10984.0  1.1
# ...           ...   ...     ...          ...  ...              ...  ...
# 460015         Y2   ZB8      08           02  ...           5724.0 -0.1
# 1851047        Y1   Z07      04           07  ...         234126.0  0.7
# 1895545        Y4   ZM8      08           45  ...         109757.0 -1.0
# 1953511        Y6   Z03      06           39  ...          27860.0  0.2
# 1828973        Y3   ZL2      01           04  ...         173261.0 -0.8
#
#                 IPI        IPRI  Temperatura_Media  Precipitacion   Sell_In_3  \
# 407595    81.089996  109.320000          11.030000      11.000000    0.200000
# 419583   103.449997  109.830002          12.290000       3.410000    0.600000
# 428870    97.739998  110.169998           9.700000      88.599998    0.000000
# 1851591  103.080002  122.430000          28.059999       4.530000  416.279999
# 402259    93.389999  108.750000           6.350000       6.820000    0.320000
# ...             ...         ...                ...            ...         ...
# 460015    96.279999  112.709999          11.450000     104.430000   15.600000
# 1851047   92.190002  121.379997          28.610001       5.820000  352.950012
# 1895545  118.489998  117.879997          22.090000      27.990000    9.030000
# 1953511  132.419998  114.279999          14.010000     178.149994    9.240000
# 1828973  111.540001  120.279999          28.129999       0.030000    0.000000
#
#           Sell_In_2   Sell_In_1     Sell_In
# 407595     0.200000    0.000000    0.100000
# 419583     1.260000    0.480000    0.960000
# 428870     0.000000    0.000000    0.300000
# 1851591  487.239990  197.759995  442.250000
# 402259     4.750000    0.000000    0.000000
# ...             ...         ...         ...
# 460015    -0.300000   20.639999   15.480000
# 1851047  271.850006  195.229996  275.700012
# 1895545   -0.170000    4.260000    2.810000
# 1953511    0.000000    4.380000    0.000000
# 1828973    4.620000    0.000000    0.000000
#
# [5705 rows x 44 columns]

# %%
df_test_pred = test.copy()
df_test_pred['Sell_In_Pred'] = model.predict(test[features])

df_test_pred[['Epoca_Covid', 'Trimestre', 'Mes', 'ID_CCAA', 'ID_Provincia', 'Gama', 'Formato', 'Sell_In', 'Sell_In_Pred']]
# Out:
#         Epoca_Covid Trimestre Mes ID_CCAA ID_Provincia Gama      Formato  \
# 407595   post-covid        T1  02      11           06  ABI  Medio Litro
# 419583   post-covid        T1  02      01           41   MH       Quinto
# 428870   post-covid        T1  03      08           02  ABI       Barril
# 1851591  post-covid        T3  08      01           23   MH       Tercio
# 402259   post-covid        T1  02      07           49   MH       Tercio
# ...             ...       ...  ..     ...          ...  ...          ...
# 460015   post-covid        T2  04      08           02   AL       Quinto
# 1851047  post-covid        T3  08      04           07   MH       Tercio
# 1895545  post-covid        T3  09      08           45  ABI       Tercio
# 1953511  post-covid        T4  11      06           39   MH       Cuarto
# 1828973  post-covid        T3  07      01           04   MH       Cuarto
#
#             Sell_In  Sell_In_Pred
# 407595     0.100000      0.037601
# 419583     0.960000      1.080268
# 428870     0.300000      0.101281
# 1851591  442.250000    452.552243
# 402259     0.000000      0.004841
# ...             ...           ...
# 460015    15.480000     19.243819
# 1851047  275.700012    241.246139
# 1895545    2.810000      0.761039
# 1953511    0.000000      0.010403
# 1828973    0.000000      0.030703
#
# [5705 rows x 9 columns]

# %% [markdown]
# ## 2.2. Eliminando variables correlacionadas

# %%
# LightGBM
# -----------------------------------------------------------------------------
import lightgbm as lgb

# %%
# Ruta
path = './data/tablon-sell-in-3.csv'


# Cargar datos
df = pd.read_csv(
    path,
    sep=';',
    dtype={
        'Epoca_Covid': 'category',
        'Anio': 'category',
        'Trimestre': 'category',
        'Mes': 'category',
        'Cliente': 'category',
        'Tipo_Cliente': 'category',
        'Distribuidor_MSM': 'category',
        'Codigo_Postal': 'category',
        'Area_Dist': 'category',
        'Zona': 'category',
        'ID_CCAA': 'category',
        'ID_Provincia': 'category',
        'Gama': 'category',
        'Formato': 'category'
    })


# Castear tipo de dato
fcols = df.select_dtypes('float').columns
icols = df.select_dtypes('integer').columns

df[fcols] = df[fcols].apply(pd.to_numeric, downcast='float')
df[icols] = df[icols].apply(pd.to_numeric, downcast='integer')


# Eliminar año 2020
filtro = (df.Anio != '2020')
# filtro = (df.Anio == '2022') & (df.Tipo_Cliente == 'CON')
# filtro = (df.Cliente == '542516')
df = df[filtro]


df.head()
# Out:
#     Fecha Epoca_Covid  Anio Trimestre Mes  Cliente Tipo_Cliente  \
# 0  201809   pre-covid  2018        T3  09  1822277          DHC
# 1  201809   pre-covid  2018        T3  09  1822277          DHC
# 2  201809   pre-covid  2018        T3  09  1822277          DHC
# 3  201809   pre-covid  2018        T3  09  1822423          DHC
# 4  201809   pre-covid  2018        T3  09  1822423          DHC
#
#   Distribuidor_MSM Codigo_Postal Area_Dist  ...        IPRI  \
# 0                0         08241        ZZ  ...  102.370003
# 1                0         08241        ZZ  ...  102.370003
# 2                0         08241        ZZ  ...  102.370003
# 3                0         07610        ZZ  ...  103.709999
# 4                0         07610        ZZ  ...  103.709999
#
#   Temperatura_Minima Temperatura_Media Temperatura_Maxima Precipitacion  \
# 0          19.420000         23.410000          27.410000     32.580002
# 1          19.420000         23.410000          27.410000     32.580002
# 2          19.420000         23.410000          27.410000     32.580002
# 3          20.459999         24.459999          28.450001     47.189999
# 4          20.459999         24.459999          28.450001     47.189999
#
#    Sell_In_3  Sell_In_2  Sell_In_1  Sell_In      STRATIO_CREATED_DATE
# 0       0.55       0.79       0.63     0.48  2023-09-06T22:37:10.734Z
# 1       2.40       3.00       3.30     2.70  2023-09-06T22:37:10.734Z
# 2       1.27       0.95       1.11     0.95  2023-09-06T22:37:10.734Z
# 3       0.20       0.00       0.20     0.10  2023-09-06T22:37:10.734Z
# 4       8.50       7.00       6.50     7.50  2023-09-06T22:37:10.734Z
#
# [5 rows x 54 columns]

# %%
# Columnas del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1897461 entries, 0 to 2232236
# Data columns (total 54 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Fecha                       int32
#  1   Epoca_Covid                 category
#  2   Anio                        category
#  3   Trimestre                   category
#  4   Mes                         category
#  5   Cliente                     category
#  6   Tipo_Cliente                category
#  7   Distribuidor_MSM            category
#  8   Codigo_Postal               category
#  9   Area_Dist                   category
#  10  Zona                        category
#  11  ID_CCAA                     category
#  12  ID_Provincia                category
#  13  Gama                        category
#  14  Formato                     category
#  15  Num_PdV_CI                  float32
#  16  Num_PdV_RU                  float32
#  17  Num_PdV_TU                  float32
#  18  Impactos_TV                 float64
#  19  Impactos_OOH                float64
#  20  Impresiones_Meta            float32
#  21  Impresiones_Pint            float32
#  22  Impresiones_Digi            float32
#  23  Sell_In_PP                  float64
#  24  Marketing_Nacional          float64
#  25  Trade_Marketing             float64
#  26  Marketing_PLV               float64
#  27  Distancia_CdP               float32
#  28  Dispersion_PdV              float32
#  29  Volumen_Solicitado          float32
#  30  Volumen_Entregado_Perfecto  float32
#  31  Nivel_Servicio              float32
#  32  Tarifa_Eur_Hl               float64
#  33  Margen_Distribuidor         float32
#  34  Num_Festivos                float32
#  35  Num_Festivos_AI             int8
#  36  Egatur                      float32
#  37  Frontur                     float64
#  38  Familitur                   float32
#  39  Movimientos_Entrada         float64
#  40  Movimientos_Salida          float64
#  41  Movimientos_Neto            float64
#  42  IPC                         float32
#  43  IPI                         float32
#  44  IPRI                        float32
#  45  Temperatura_Minima          float32
#  46  Temperatura_Media           float32
#  47  Temperatura_Maxima          float32
#  48  Precipitacion               float32
#  49  Sell_In_3                   float32
#  50  Sell_In_2                   float32
#  51  Sell_In_1                   float32
#  52  Sell_In                     float32
#  53  STRATIO_CREATED_DATE        object
# dtypes: category(14), float32(26), float64(11), int32(1), int8(1), object(1)
# memory usage: 415.1+ MB

# %%
# Eliminar columnas
df = df.drop(columns=[
    'Fecha',
    'Anio',
    'Cliente',
    'Codigo_Postal',
    'Frontur',
    'Temperatura_Minima',
    'Temperatura_Maxima',
    'Movimientos_Entrada',
    'Movimientos_Salida',
    #'Volumen_Solicitado',
    'Volumen_Entregado_Perfecto',
    #'Sell_In_PP',
    #'Sell_In_3',
    #'Sell_In_2',
    #'Sell_In_1',
    #'Marketing_Nacional',
    #'Trade_Marketing',
    #'Marketing_PLV',
    'STRATIO_CREATED_DATE'
])

# Eliminar registros con NaN
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1897461 entries, 0 to 2232236
# Data columns (total 43 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Epoca_Covid          category
#  1   Trimestre            category
#  2   Mes                  category
#  3   Tipo_Cliente         category
#  4   Distribuidor_MSM     category
#  5   Area_Dist            category
#  6   Zona                 category
#  7   ID_CCAA              category
#  8   ID_Provincia         category
#  9   Gama                 category
#  10  Formato              category
#  11  Num_PdV_CI           float32
#  12  Num_PdV_RU           float32
#  13  Num_PdV_TU           float32
#  14  Impactos_TV          float64
#  15  Impactos_OOH         float64
#  16  Impresiones_Meta     float32
#  17  Impresiones_Pint     float32
#  18  Impresiones_Digi     float32
#  19  Sell_In_PP           float64
#  20  Marketing_Nacional   float64
#  21  Trade_Marketing      float64
#  22  Marketing_PLV        float64
#  23  Distancia_CdP        float32
#  24  Dispersion_PdV       float32
#  25  Volumen_Solicitado   float32
#  26  Nivel_Servicio       float32
#  27  Tarifa_Eur_Hl        float64
#  28  Margen_Distribuidor  float32
#  29  Num_Festivos         float32
#  30  Num_Festivos_AI      int8
#  31  Egatur               float32
#  32  Familitur            float32
#  33  Movimientos_Neto     float64
#  34  IPC                  float32
#  35  IPI                  float32
#  36  IPRI                 float32
#  37  Temperatura_Media    float32
#  38  Precipitacion        float32
#  39  Sell_In_3            float32
#  40  Sell_In_2            float32
#  41  Sell_In_1            float32
#  42  Sell_In              float32
# dtypes: category(11), float32(23), float64(8), int8(1)
# memory usage: 318.5 MB

# %% [markdown]
# ### 2.2.1. Modelo base I

# %%
# Variable dependiente
target = 'Sell_In'

# Variables independientes
features = list(df.columns)
features.remove(target)

# Mostrar
print(f'Variable dependiente: {target}')
print(30*'-')
print(f'Variable independiente: {features}')
# Out:
# Variable dependiente: Sell_In
# ------------------------------
# Variable independiente: ['Epoca_Covid', 'Trimestre', 'Mes', 'Tipo_Cliente', 'Distribuidor_MSM', 'Area_Dist', 'Zona', 'ID_CCAA', 'ID_Provincia', 'Gama', 'Formato', 'Num_PdV_CI', 'Num_PdV_RU', 'Num_PdV_TU', 'Impactos_TV', 'Impactos_OOH', 'Impresiones_Meta', 'Impresiones_Pint', 'Impresiones_Digi', 'Sell_In_PP', 'Marketing_Nacional', 'Trade_Marketing', 'Marketing_PLV', 'Distancia_CdP', 'Dispersion_PdV', 'Volumen_Solicitado', 'Nivel_Servicio', 'Tarifa_Eur_Hl', 'Margen_Distribuidor', 'Num_Festivos', 'Num_Festivos_AI', 'Egatur', 'Familitur', 'Movimientos_Neto', 'IPC', 'IPI', 'IPRI', 'Temperatura_Media', 'Precipitacion', 'Sell_In_3', 'Sell_In_2', 'Sell_In_1']

# %%
# Seed
seed = 123

# Separar conjunto de test y entrenamiento
train, test = train_test_split(df, train_size=0.95, test_size=0.05, random_state=seed)

# %%
# Instanciar modelo
mlgb = lgb.LGBMRegressor(
    boosting_type = 'gbdt', # Gradient Boosting Decision Tree
    learning_rate = 0.1, # Boosting learning rate (default value)
    n_estimators = 1000, # Número de árboles (originalmente 1000)
    max_depth = max_depth, # Profundidad máxima del árbol [3, 12]
    num_leaves = 80, # Número de hojas máximo del árbol, <2^max_depth
    min_child_samples = 10, # Número mínimo de registros en una hoja
    bagging_fraction = 1.0, # Porcentaje de datos cogidos en cada re-sampling del Bagging
    bagging_freq = 0, # Frecuencia del Bagging
    feature_fraction = 0.9, # Feature sub-sampling
    reg_sqrt = True, # Raíz cuadrada del target, para variables a predecir con mucha variabilidad
    extra_trees = True, # Incremente velocidad, disminuye overfitting
    feature_pre_filter = False,
    random_state = seed,
    n_jobs = -1
)

# %%
# Pipeline
model_pipeline = Pipeline(steps=[("mlgb", mlgb)])

# %%
# Medir tiempo
tiempo_inicial = time()

# Entrenar modelo
model = model_pipeline.fit(train[features], train[target])

# Medir tiempo
tiempo_final = time()
tiempo_ejecucion = tiempo_final - tiempo_inicial

print('')
print(f'El tiempo de ejecución es de {tiempo_ejecucion/60} minutos')
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#
# El tiempo de ejecución es de 1.0654676795005797 minutos

# %%
# Cálculo de métricas
train_y_real = train[target]
train_y_pred = model.predict(train[features])

test_y_real = test[target]
test_y_pred = model.predict(test[features])

metric_test_r2 = round(r2_score(test_y_real, test_y_pred), 3)
metric_adj_test_r2 = round(1-(1-metric_test_r2)*(len(test)-1)/(len(test)-len(features)-1), 3)

metric_train_mae = round(mean_absolute_error(train_y_real, train_y_pred), 3)
metric_test_mae = round(mean_absolute_error(test_y_real, test_y_pred), 3)

metric_train_rmse = round(mean_squared_error(train_y_real, train_y_pred, squared=False), 3)
metric_test_rmse = round(mean_squared_error(test_y_real, test_y_pred, squared=False), 3)

metric_train_score = round(1.00 - (metric_train_mae / train_y_real.mean()), 3)
metric_test_score = round(1.00 - (metric_test_mae / test_y_real.mean()), 3)


# Mostrar
print('R2 Score')
print(50*'-')
print(f'Test R2: {metric_test_r2}')
print(f'Test R2 Adj: {metric_adj_test_r2}')
print('')

print('Score')
print(50*'-')
print(f'Train: {metric_train_score}')
print(f'Test: {metric_test_score}')
print('')

print('MAE')
print(50*'-')
print(f'Train: {metric_train_mae}')
print(f'Test: {metric_test_mae}')
print('')

print('RMSE')
print(50*'-')
print(f'Train: {metric_train_rmse}')
print(f'Test: {metric_test_rmse}')
print('')
# Out:
# R2 Score
# --------------------------------------------------
# Test R2: 0.958
# Test R2 Adj: 0.958
#
# Score
# --------------------------------------------------
# Train: 0.841
# Test: 0.797
#
# MAE
# --------------------------------------------------
# Train: 2.95
# Test: 3.868
#
# RMSE
# --------------------------------------------------
# Train: 20.601
# Test: 31.908

# %%
feature_imp = pd.DataFrame(sorted(zip(features, model[0].feature_importances_)), columns=['Feature', 'Value'])
feature_imp = feature_imp.sort_values(by=['Value'], ascending=False).reset_index(drop=True)
feature_imp
# Out:
#                 Feature  Value
# 0          ID_Provincia   7808
# 1                   Mes   6828
# 2         Marketing_PLV   3574
# 3               Formato   3207
# 4            Sell_In_PP   3119
# 5       Trade_Marketing   2955
# 6             Sell_In_1   2870
# 7    Marketing_Nacional   2793
# 8             Sell_In_3   2785
# 9                  Gama   2600
# 10            Sell_In_2   2564
# 11   Volumen_Solicitado   2508
# 12           Num_PdV_CI   2473
# 13                 Zona   2245
# 14            Familitur   2097
# 15          Epoca_Covid   2090
# 16       Dispersion_PdV   1697
# 17        Precipitacion   1544
# 18            Area_Dist   1447
# 19        Tarifa_Eur_Hl   1426
# 20                 IPRI   1397
# 21           Num_PdV_TU   1388
# 22  Margen_Distribuidor   1325
# 23          Impactos_TV   1284
# 24              ID_CCAA   1257
# 25         Num_Festivos   1216
# 26     Impresiones_Meta   1184
# 27               Egatur   1091
# 28           Num_PdV_RU   1070
# 29    Temperatura_Media   1060
# 30                  IPI   1040
# 31            Trimestre   1026
# 32        Distancia_CdP   1013
# 33     Distribuidor_MSM    950
# 34         Tipo_Cliente    935
# 35     Movimientos_Neto    890
# 36                  IPC    532
# 37     Impresiones_Digi    474
# 38      Num_Festivos_AI    446
# 39       Nivel_Servicio    297
# 40     Impresiones_Pint    269
# 41         Impactos_OOH    226

# %%
# Figure aesthetics
sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(8, 12))

# Barplot
sns.barplot(
    x='Value',
    y='Feature',
    data=feature_imp
)

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Features')

# Add values
ax.bar_label(ax.containers[0], label_type='edge', fmt='{:,.0f}', padding=5)

# Show the plot
sns.despine()

# %% [markdown]
# ### 2.2.2. Modelo base II (Definitivo)

# %%
# Ruta
path = './data/tablon-sell-in-3.csv'


# Cargar datos
df = pd.read_csv(
    path,
    sep=';',
    dtype={
        'Epoca_Covid': 'category',
        'Anio': 'category',
        'Trimestre': 'category',
        'Mes': 'category',
        'Cliente': 'category',
        'Tipo_Cliente': 'category',
        'Distribuidor_MSM': 'category',
        'Codigo_Postal': 'category',
        'Area_Dist': 'category',
        'Zona': 'category',
        'ID_CCAA': 'category',
        'ID_Provincia': 'category',
        'Gama': 'category',
        'Formato': 'category'
    })


# Castear tipo de dato
fcols = df.select_dtypes('float').columns
icols = df.select_dtypes('integer').columns

df[fcols] = df[fcols].apply(pd.to_numeric, downcast='float')
df[icols] = df[icols].apply(pd.to_numeric, downcast='integer')


# Eliminar año 2020
filtro = (df.Anio != '2020')
# filtro = (df.Anio == '2022') & (df.Tipo_Cliente == 'CON')
# filtro = (df.Cliente == '542516')
df = df[filtro]


df.head()
# Out:
#     Fecha Epoca_Covid  Anio Trimestre Mes  Cliente Tipo_Cliente  \
# 0  201809   pre-covid  2018        T3  09  1822277          DHC
# 1  201809   pre-covid  2018        T3  09  1822277          DHC
# 2  201809   pre-covid  2018        T3  09  1822277          DHC
# 3  201809   pre-covid  2018        T3  09  1822423          DHC
# 4  201809   pre-covid  2018        T3  09  1822423          DHC
#
#   Distribuidor_MSM Codigo_Postal Area_Dist  ...        IPRI  \
# 0                0         08241        ZZ  ...  102.370003
# 1                0         08241        ZZ  ...  102.370003
# 2                0         08241        ZZ  ...  102.370003
# 3                0         07610        ZZ  ...  103.709999
# 4                0         07610        ZZ  ...  103.709999
#
#   Temperatura_Minima Temperatura_Media Temperatura_Maxima Precipitacion  \
# 0          19.420000         23.410000          27.410000     32.580002
# 1          19.420000         23.410000          27.410000     32.580002
# 2          19.420000         23.410000          27.410000     32.580002
# 3          20.459999         24.459999          28.450001     47.189999
# 4          20.459999         24.459999          28.450001     47.189999
#
#    Sell_In_3  Sell_In_2  Sell_In_1  Sell_In      STRATIO_CREATED_DATE
# 0       0.55       0.79       0.63     0.48  2023-09-06T22:37:10.734Z
# 1       2.40       3.00       3.30     2.70  2023-09-06T22:37:10.734Z
# 2       1.27       0.95       1.11     0.95  2023-09-06T22:37:10.734Z
# 3       0.20       0.00       0.20     0.10  2023-09-06T22:37:10.734Z
# 4       8.50       7.00       6.50     7.50  2023-09-06T22:37:10.734Z
#
# [5 rows x 54 columns]

# %%
# Eliminar columnas
df = df.drop(columns=[
    'Fecha',
    'Anio',
    'Cliente',
    'Codigo_Postal',
    'Frontur',
    'Temperatura_Minima',
    'Temperatura_Maxima',
    'Movimientos_Entrada',
    'Movimientos_Salida',
    #'Volumen_Solicitado',
    'Volumen_Entregado_Perfecto',
    #'Sell_In_PP',
    'Sell_In_3',
    'Sell_In_2',
    #'Sell_In_1',
    #'Marketing_Nacional',
    #'Trade_Marketing',
    #'Marketing_PLV',
    'STRATIO_CREATED_DATE'
])

# Eliminar registros con NaN
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1897461 entries, 0 to 2232236
# Data columns (total 41 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Epoca_Covid          category
#  1   Trimestre            category
#  2   Mes                  category
#  3   Tipo_Cliente         category
#  4   Distribuidor_MSM     category
#  5   Area_Dist            category
#  6   Zona                 category
#  7   ID_CCAA              category
#  8   ID_Provincia         category
#  9   Gama                 category
#  10  Formato              category
#  11  Num_PdV_CI           float32
#  12  Num_PdV_RU           float32
#  13  Num_PdV_TU           float32
#  14  Impactos_TV          float64
#  15  Impactos_OOH         float64
#  16  Impresiones_Meta     float32
#  17  Impresiones_Pint     float32
#  18  Impresiones_Digi     float32
#  19  Sell_In_PP           float64
#  20  Marketing_Nacional   float64
#  21  Trade_Marketing      float64
#  22  Marketing_PLV        float64
#  23  Distancia_CdP        float32
#  24  Dispersion_PdV       float32
#  25  Volumen_Solicitado   float32
#  26  Nivel_Servicio       float32
#  27  Tarifa_Eur_Hl        float64
#  28  Margen_Distribuidor  float32
#  29  Num_Festivos         float32
#  30  Num_Festivos_AI      int8
#  31  Egatur               float32
#  32  Familitur            float32
#  33  Movimientos_Neto     float64
#  34  IPC                  float32
#  35  IPI                  float32
#  36  IPRI                 float32
#  37  Temperatura_Media    float32
#  38  Precipitacion        float32
#  39  Sell_In_1            float32
#  40  Sell_In              float32
# dtypes: category(11), float32(21), float64(8), int8(1)
# memory usage: 304.0 MB

# %%
# Variable dependiente
target = 'Sell_In'

# Variables independientes
features = list(df.columns)
features.remove(target)

# Mostrar
print(f'Variable dependiente: {target}')
print(30*'-')
print(f'Variable independiente: {features}')
# Out:
# Variable dependiente: Sell_In
# ------------------------------
# Variable independiente: ['Epoca_Covid', 'Trimestre', 'Mes', 'Tipo_Cliente', 'Distribuidor_MSM', 'Area_Dist', 'Zona', 'ID_CCAA', 'ID_Provincia', 'Gama', 'Formato', 'Num_PdV_CI', 'Num_PdV_RU', 'Num_PdV_TU', 'Impactos_TV', 'Impactos_OOH', 'Impresiones_Meta', 'Impresiones_Pint', 'Impresiones_Digi', 'Sell_In_PP', 'Marketing_Nacional', 'Trade_Marketing', 'Marketing_PLV', 'Distancia_CdP', 'Dispersion_PdV', 'Volumen_Solicitado', 'Nivel_Servicio', 'Tarifa_Eur_Hl', 'Margen_Distribuidor', 'Num_Festivos', 'Num_Festivos_AI', 'Egatur', 'Familitur', 'Movimientos_Neto', 'IPC', 'IPI', 'IPRI', 'Temperatura_Media', 'Precipitacion', 'Sell_In_1']

# %%
# Seed
seed = 123

# Separar conjunto de test y entrenamiento
train, test = train_test_split(df, train_size=0.95, test_size=0.05, random_state=seed)

# %%
# Instanciar modelo
mlgb = lgb.LGBMRegressor(
    boosting_type = 'gbdt', # Gradient Boosting Decision Tree
    learning_rate = 0.1, # Boosting learning rate (default value)
    n_estimators = 1000, # Número de árboles (originalmente 1000)
    max_depth = max_depth, # Profundidad máxima del árbol [3, 12]
    num_leaves = 80, # Número de hojas máximo del árbol, <2^max_depth
    min_child_samples = 10, # Número mínimo de registros en una hoja
    bagging_fraction = 1.0, # Porcentaje de datos cogidos en cada re-sampling del Bagging
    bagging_freq = 0, # Frecuencia del Bagging
    feature_fraction = 0.9, # Feature sub-sampling
    reg_sqrt = True, # Raíz cuadrada del target, para variables a predecir con mucha variabilidad
    extra_trees = True, # Incremente velocidad, disminuye overfitting
    feature_pre_filter = False,
    random_state = seed,
    n_jobs = -1
)

# %%
# Pipeline
model_pipeline = Pipeline(steps=[("mlgb", mlgb)])

# %%
# Medir tiempo
tiempo_inicial = time()

# Entrenar modelo
model = model_pipeline.fit(train[features], train[target])

# Medir tiempo
tiempo_final = time()
tiempo_ejecucion = tiempo_final - tiempo_inicial

print('')
print(f'El tiempo de ejecución es de {tiempo_ejecucion/60} minutos')
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#
# El tiempo de ejecución es de 0.9252092242240906 minutos

# %%
# Cálculo de métricas
train_y_real = train[target]
train_y_pred = model.predict(train[features])

test_y_real = test[target]
test_y_pred = model.predict(test[features])

metric_test_r2 = round(r2_score(test_y_real, test_y_pred), 3)
metric_adj_test_r2 = round(1-(1-metric_test_r2)*(len(test)-1)/(len(test)-len(features)-1), 3)

metric_train_mae = round(mean_absolute_error(train_y_real, train_y_pred), 3)
metric_test_mae = round(mean_absolute_error(test_y_real, test_y_pred), 3)

metric_train_rmse = round(mean_squared_error(train_y_real, train_y_pred, squared=False), 3)
metric_test_rmse = round(mean_squared_error(test_y_real, test_y_pred, squared=False), 3)

metric_train_score = round(1.00 - (metric_train_mae / train_y_real.mean()), 3)
metric_test_score = round(1.00 - (metric_test_mae / test_y_real.mean()), 3)


# Mostrar
print('R2 Score')
print(50*'-')
print(f'Test R2: {metric_test_r2}')
print(f'Test R2 Adj: {metric_adj_test_r2}')
print('')

print('Score')
print(50*'-')
print(f'Train: {metric_train_score}')
print(f'Test: {metric_test_score}')
print('')

print('MAE')
print(50*'-')
print(f'Train: {metric_train_mae}')
print(f'Test: {metric_test_mae}')
print('')

print('RMSE')
print(50*'-')
print(f'Train: {metric_train_rmse}')
print(f'Test: {metric_test_rmse}')
print('')
# Out:
# R2 Score
# --------------------------------------------------
# Test R2: 0.955
# Test R2 Adj: 0.955
#
# Score
# --------------------------------------------------
# Train: 0.831
# Test: 0.79
#
# MAE
# --------------------------------------------------
# Train: 3.145
# Test: 4.004
#
# RMSE
# --------------------------------------------------
# Train: 22.429
# Test: 32.922

# %%
feature_imp = pd.DataFrame(sorted(zip(features, model[0].feature_importances_)), columns=['Feature', 'Value'])
feature_imp = feature_imp.sort_values(by=['Value'], ascending=False).reset_index(drop=True)
feature_imp
# Out:
#                 Feature  Value
# 0          ID_Provincia   8150
# 1                   Mes   6351
# 2         Marketing_PLV   3813
# 3            Sell_In_PP   3723
# 4             Sell_In_1   3701
# 5               Formato   3701
# 6    Marketing_Nacional   3191
# 7       Trade_Marketing   3137
# 8                  Gama   3079
# 9            Num_PdV_CI   2722
# 10   Volumen_Solicitado   2666
# 11                 Zona   2287
# 12          Epoca_Covid   2266
# 13            Familitur   2086
# 14       Dispersion_PdV   1916
# 15        Tarifa_Eur_Hl   1694
# 16            Area_Dist   1618
# 17  Margen_Distribuidor   1610
# 18        Precipitacion   1513
# 19           Num_PdV_TU   1402
# 20              ID_CCAA   1388
# 21                 IPRI   1346
# 22          Impactos_TV   1345
# 23           Num_PdV_RU   1293
# 24     Impresiones_Meta   1222
# 25        Distancia_CdP   1184
# 26         Num_Festivos   1181
# 27               Egatur   1087
# 28     Distribuidor_MSM   1067
# 29                  IPI   1067
# 30    Temperatura_Media   1020
# 31            Trimestre    955
# 32     Movimientos_Neto    937
# 33         Tipo_Cliente    937
# 34                  IPC    578
# 35     Impresiones_Digi    449
# 36      Num_Festivos_AI    438
# 37       Nivel_Servicio    335
# 38     Impresiones_Pint    315
# 39         Impactos_OOH    230

# %%
# Figure aesthetics
sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(8, 12))

# Barplot
sns.barplot(
    x='Value',
    y='Feature',
    data=feature_imp
)

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Features')

# Add values
ax.bar_label(ax.containers[0], label_type='edge', fmt='{:,.0f}', padding=5)

# Show the plot
sns.despine()

# %% [markdown]
# #### 2.2.2.1. Modelo base II optimizado I

# %%
# scikit-learn
# -----------------------------------------------------------------------------
from sklearn.model_selection import train_test_split, KFold


# Optuna
# -----------------------------------------------------------------------------
import optuna
import optuna.integration.lightgbm as lgb
optuna.logging.set_verbosity(optuna.logging.FATAL)


# LightGBM
# -----------------------------------------------------------------------------
from lightgbm import early_stopping
from lightgbm import log_evaluation

# %%
# Instanciar optimizador
dtrain = lgb.Dataset(train[features], label=train[target])

# %%
# Parametros de optimización
max_depth = 8

params = {
    'objective': 'regression',
    'verbosity': -1,
    'metric': 'l1', # mean_absolute_error
    'boosting_type': 'gbdt',
    'max_depth': max_depth,
    'reg_sqrt': True,
    'seed': seed
    }

# %%
# Optimizador
tuner = lgb.LightGBMTunerCV(
    params,
    dtrain,
    folds=KFold(n_splits=3),
    #callbacks=[early_stopping(300), log_evaluation(100)]
    )

# %%
# Medir tiempo
tiempo_inicial = time()

# Ejecutar optmizador
tuner.run()

# Medir tiempo
tiempo_final = time()
tiempo_ejecucion = tiempo_final - tiempo_inicial

print('')
print(f'El tiempo de ejecución es de {tiempo_ejecucion/60} minutos')
# Out:
# feature_fraction, val_score: 3.904501: 100%|#############| 7/7 [15:00<00:00, 128.65s/it]
# num_leaves, val_score: 3.653568: 100%|###############| 20/20 [1:07:47<00:00, 203.38s/it]
# bagging, val_score: 3.653568: 100%|####################| 10/10 [43:51<00:00, 263.11s/it]
# feature_fraction_stage2, val_score: 3.652841: 100%|######| 6/6 [29:21<00:00, 293.54s/it]
# regularization_factors, val_score: 3.617216: 100%|###| 20/20 [1:17:16<00:00, 231.84s/it]
# min_data_in_leaf, val_score: 3.602356: 100%|#############| 5/5 [20:02<00:00, 240.49s/it]
# El tiempo de ejecución es de 253.3303634484609 minutos

# %%
# Mejores parámetros
best_params = tuner.best_params
best_params
# Out:
# {'objective': 'regression',
#  'verbosity': -1,
#  'metric': 'l1',
#  'boosting_type': 'gbdt',
#  'max_depth': 8,
#  'reg_sqrt': True,
#  'seed': 123,
#  'feature_pre_filter': False,
#  'lambda_l1': 8.462142421036356,
#  'lambda_l2': 5.3428959189446825,
#  'num_leaves': 141,
#  'feature_fraction': 0.82,
#  'bagging_fraction': 1.0,
#  'bagging_freq': 0,
#  'min_child_samples': 5}

# %%
# LightGBM
# -----------------------------------------------------------------------------
import lightgbm as lgb

# Instanciar modelo
mlgb = lgb.LGBMRegressor(
    boosting_type = 'gbdt',
    learning_rate = 0.1,
    n_estimators = 1000,
    max_depth = max_depth,
    num_leaves = best_params['num_leaves'],
    min_child_samples = best_params['min_child_samples'],
    bagging_fraction = best_params['bagging_fraction'],
    bagging_freq = best_params['bagging_freq'],
    feature_fraction = best_params['feature_fraction'],
    reg_alpha = best_params['lambda_l1'],
    reg_lambda = best_params['lambda_l2'],
    reg_sqrt = True,
    extra_trees = True,
    feature_pre_filter = False,
    random_state = seed,
    n_jobs = -1
)

# Pipeline
model_pipeline = Pipeline(steps=[("mlgb", mlgb)])

# Entrenar modelo
model = model_pipeline.fit(train[features], train[target])


# Cálculo de métricas
train_y_real = train[target]
train_y_pred = model.predict(train[features])
test_y_real = test[target]
test_y_pred = model.predict(test[features])

metric_test_r2 = round(r2_score(test_y_real, test_y_pred), 3)
metric_adj_test_r2 = round(1-(1-metric_test_r2)*(len(test)-1)/(len(test)-len(features)-1), 3)

metric_train_mae = round(mean_absolute_error(train_y_real, train_y_pred), 3)
metric_test_mae = round(mean_absolute_error(test_y_real, test_y_pred), 3)

metric_train_rmse = round(mean_squared_error(train_y_real, train_y_pred, squared=False), 3)
metric_test_rmse = round(mean_squared_error(test_y_real, test_y_pred, squared=False), 3)

metric_train_score = round(1.00 - (metric_train_mae / train_y_real.mean()), 3)
metric_test_score = round(1.00 - (metric_test_mae / test_y_real.mean()), 3)


# Mostrar
print('R2 Score')
print(50*'-')
print(f'Test R2: {metric_test_r2}')
print(f'Test R2 Adj: {metric_adj_test_r2}')
print('')

print('Score')
print(50*'-')
print(f'Train: {metric_train_score}')
print(f'Test: {metric_test_score}')
print('')

print('MAE')
print(50*'-')
print(f'Train: {metric_train_mae}')
print(f'Test: {metric_test_mae}')
print('')

print('RMSE')
print(50*'-')
print(f'Train: {metric_train_rmse}')
print(f'Test: {metric_test_rmse}')
print('')
# Out:
# R2 Score
# --------------------------------------------------
# Test R2: 0.956
# Test R2 Adj: 0.956
#
# Score
# --------------------------------------------------
# Train: 0.826
# Test: 0.791
#
# MAE
# --------------------------------------------------
# Train: 3.227
# Test: 3.99
#
# RMSE
# --------------------------------------------------
# Train: 25.806
# Test: 32.514

# %%
feature_imp = pd.DataFrame(sorted(zip(features, model[0].feature_importances_)), columns=['Feature', 'Value'])
feature_imp = feature_imp.sort_values(by=['Value'], ascending=False).reset_index(drop=True)
feature_imp
# Out:
#                 Feature  Value
# 0          ID_Provincia  18608
# 1                   Mes  16905
# 2               Formato  10340
# 3                  Gama   8387
# 4                  Zona   7068
# 5             Area_Dist   6022
# 6             Sell_In_1   5029
# 7            Sell_In_PP   4976
# 8         Marketing_PLV   4568
# 9               ID_CCAA   4487
# 10      Trade_Marketing   4057
# 11   Marketing_Nacional   4043
# 12            Trimestre   3706
# 13   Volumen_Solicitado   3548
# 14           Num_PdV_CI   3078
# 15          Epoca_Covid   2842
# 16            Familitur   2676
# 17        Tarifa_Eur_Hl   2159
# 18       Dispersion_PdV   2116
# 19  Margen_Distribuidor   1870
# 20                 IPRI   1756
# 21           Num_PdV_TU   1650
# 22          Impactos_TV   1512
# 23        Precipitacion   1469
# 24     Impresiones_Meta   1410
# 25           Num_PdV_RU   1366
# 26         Tipo_Cliente   1343
# 27     Distribuidor_MSM   1244
# 28         Num_Festivos   1000
# 29               Egatur    965
# 30    Temperatura_Media    893
# 31                  IPI    842
# 32        Distancia_CdP    829
# 33                  IPC    726
# 34     Impresiones_Digi    684
# 35     Movimientos_Neto    648
# 36     Impresiones_Pint    527
# 37       Nivel_Servicio    454
# 38      Num_Festivos_AI    380
# 39         Impactos_OOH    343

# %%
# Figure aesthetics
sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(8, 12))

# Barplot
sns.barplot(
    x='Value',
    y='Feature',
    data=feature_imp
)

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Features')

# Add values
ax.bar_label(ax.containers[0], label_type='edge', fmt='{:,.0f}', padding=5)

# Show the plot
sns.despine()

# %% [markdown]
# #### 2.2.2.2. Modelo base II optimizado II

# %%
# scikit-learn
# -----------------------------------------------------------------------------
from sklearn.model_selection import train_test_split, KFold


# Optuna
# -----------------------------------------------------------------------------
import optuna
import optuna.integration.lightgbm as lgb
optuna.logging.set_verbosity(optuna.logging.FATAL)


# LightGBM
# -----------------------------------------------------------------------------
from lightgbm import early_stopping
from lightgbm import log_evaluation

# %%
# Instanciar optimizador
dtrain = lgb.Dataset(train[features], label=train[target])

# %%
# Parametros de optimización
max_depth = 10

params = {
    'objective': 'regression',
    'verbosity': -1,
    'metric': 'l1', # mean_absolute_error
    'boosting_type': 'gbdt',
    'max_depth': max_depth,
    'reg_sqrt': True,
    'seed': seed
    }

# %%
# Optimizador
tuner = lgb.LightGBMTunerCV(
    params,
    dtrain,
    folds=KFold(n_splits=3),
    #callbacks=[early_stopping(300), log_evaluation(100)]
    )

# %%
# Medir tiempo
tiempo_inicial = time()

# Ejecutar optmizador
tuner.run()

# Medir tiempo
tiempo_final = time()
tiempo_ejecucion = tiempo_final - tiempo_inicial

print('')
print(f'El tiempo de ejecución es de {tiempo_ejecucion/60} minutos')
# Out:
# feature_fraction, val_score: 3.896479: 100%|#############| 7/7 [12:42<00:00, 108.90s/it]
# num_leaves, val_score: 3.581426: 100%|###############| 20/20 [1:25:00<00:00, 255.02s/it]
# bagging, val_score: 3.581426: 100%|####################| 10/10 [45:59<00:00, 275.91s/it]
# feature_fraction_stage2, val_score: 3.571066: 100%|######| 6/6 [24:40<00:00, 246.73s/it]
# regularization_factors, val_score: 3.537347: 100%|###| 20/20 [1:22:56<00:00, 248.82s/it]
# min_data_in_leaf, val_score: 3.530593: 100%|#############| 5/5 [20:08<00:00, 241.66s/it]
# El tiempo de ejecución es de 271.4476925611496 minutos

# %%
# Mejores parámetros
best_params = tuner.best_params
best_params
# Out:
# {'objective': 'regression',
#  'verbosity': -1,
#  'metric': 'l1',
#  'boosting_type': 'gbdt',
#  'max_depth': 10,
#  'reg_sqrt': True,
#  'seed': 123,
#  'feature_pre_filter': False,
#  'lambda_l1': 8.984891066795668e-07,
#  'lambda_l2': 8.901788949599446,
#  'num_leaves': 309,
#  'feature_fraction': 0.82,
#  'bagging_fraction': 1.0,
#  'bagging_freq': 0,
#  'min_child_samples': 25}

# %%
# LightGBM
# -----------------------------------------------------------------------------
import lightgbm as lgb

# Instanciar modelo
mlgb = lgb.LGBMRegressor(
    boosting_type = 'gbdt',
    learning_rate = 0.1,
    n_estimators = 1000,
    max_depth = max_depth,
    num_leaves = best_params['num_leaves'],
    min_child_samples = best_params['min_child_samples'],
    bagging_fraction = best_params['bagging_fraction'],
    bagging_freq = best_params['bagging_freq'],
    feature_fraction = best_params['feature_fraction'],
    reg_alpha = best_params['lambda_l1'],
    reg_lambda = best_params['lambda_l2'],
    reg_sqrt = True,
    extra_trees = True,
    feature_pre_filter = False,
    random_state = seed,
    n_jobs = -1
)

# Pipeline
model_pipeline = Pipeline(steps=[("mlgb", mlgb)])

# Entrenar modelo
model = model_pipeline.fit(train[features], train[target])


# Cálculo de métricas
train_y_real = train[target]
train_y_pred = model.predict(train[features])

test_y_real = test[target]
test_y_pred = model.predict(test[features])

metric_test_r2 = round(r2_score(test_y_real, test_y_pred), 3)
metric_adj_test_r2 = round(1-(1-metric_test_r2)*(len(test)-1)/(len(test)-len(features)-1), 3)

metric_train_mae = round(mean_absolute_error(train_y_real, train_y_pred), 3)
metric_test_mae = round(mean_absolute_error(test_y_real, test_y_pred), 3)

metric_train_rmse = round(mean_squared_error(train_y_real, train_y_pred, squared=False), 3)
metric_test_rmse = round(mean_squared_error(test_y_real, test_y_pred, squared=False), 3)

metric_train_score = round(1.00 - (metric_train_mae / train_y_real.mean()), 3)
metric_test_score = round(1.00 - (metric_test_mae / test_y_real.mean()), 3)


# Mostrar
print('R2 Score')
print(50*'-')
print(f'Test R2: {metric_test_r2}')
print(f'Test R2 Adj: {metric_adj_test_r2}')
print('')

print('Score')
print(50*'-')
print(f'Train: {metric_train_score}')
print(f'Test: {metric_test_score}')
print('')

print('MAE')
print(50*'-')
print(f'Train: {metric_train_mae}')
print(f'Test: {metric_test_mae}')
print('')

print('RMSE')
print(50*'-')
print(f'Train: {metric_train_rmse}')
print(f'Test: {metric_test_rmse}')
print('')
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.82, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.82
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# R2 Score
# --------------------------------------------------
# Test R2: 0.963
# Test R2 Adj: 0.963
#
# Score
# --------------------------------------------------
# Train: 0.865
# Test: 0.806
#
# MAE
# --------------------------------------------------
# Train: 2.517
# Test: 3.706
#
# RMSE
# --------------------------------------------------
# Train: 18.847
# Test: 29.984

# %%
feature_imp = pd.DataFrame(sorted(zip(features, model[0].feature_importances_)), columns=['Feature', 'Value'])
feature_imp = feature_imp.sort_values(by=['Value'], ascending=False).reset_index(drop=True)
feature_imp
# Out:
#                 Feature  Value
# 0          ID_Provincia  29944
# 1                   Mes  27327
# 2               Formato  15634
# 3                  Gama  13814
# 4                  Zona  12296
# 5         Marketing_PLV  12025
# 6            Sell_In_PP  11788
# 7    Marketing_Nacional  10769
# 8            Num_PdV_CI  10376
# 9           Epoca_Covid   9735
# 10      Trade_Marketing   9727
# 11            Area_Dist   9501
# 12            Familitur   9160
# 13            Sell_In_1   8948
# 14       Dispersion_PdV   8751
# 15              ID_CCAA   7795
# 16        Precipitacion   7096
# 17            Trimestre   6955
# 18   Volumen_Solicitado   6379
# 19  Margen_Distribuidor   6049
# 20        Tarifa_Eur_Hl   5891
# 21          Impactos_TV   5730
# 22     Impresiones_Meta   5273
# 23           Num_PdV_RU   5175
# 24                 IPRI   5169
# 25           Num_PdV_TU   5153
# 26         Num_Festivos   4956
# 27                  IPI   4312
# 28        Distancia_CdP   4291
# 29    Temperatura_Media   4260
# 30               Egatur   4093
# 31     Movimientos_Neto   3545
# 32         Tipo_Cliente   3114
# 33     Distribuidor_MSM   3106
# 34                  IPC   1720
# 35     Impresiones_Digi   1645
# 36      Num_Festivos_AI   1185
# 37     Impresiones_Pint   1032
# 38         Impactos_OOH    924
# 39       Nivel_Servicio    884

# %%
# Figure aesthetics
sns.set_theme(style="whitegrid")
sns.set_context("paper")

# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(8, 12))

# Barplot
sns.barplot(
    x='Value',
    y='Feature',
    data=feature_imp
)

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Features')

# Add values
ax.bar_label(ax.containers[0], label_type='edge', fmt='{:,.0f}', padding=5)

# Show the plot
sns.despine()
